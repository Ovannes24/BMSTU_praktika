# %%
from bt_functions.f_table import redate_data
from bt_classes._backtest import BackTest

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
import plotly.graph_objects as go
import plotly.express as px
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

from plotly.offline import init_notebook_mode, iplot

# %%
AAPL = pd.read_csv('datasets/AAPL_max.csv', parse_dates=['Date'], index_col=['Date'])
AAPL
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100178    0.100614    0.100178    0.100178  469033600
# 1980-12-15    0.095388    0.095388    0.094952    0.094952  175884800
# 1980-12-16    0.088418    0.088418    0.087983    0.087983  105728000
# 1980-12-17    0.090160    0.090596    0.090160    0.090160   86441600
# 1980-12-18    0.092774    0.093210    0.092774    0.092774   73449600
# ...                ...         ...         ...         ...        ...
# 2022-07-11  145.669998  146.639999  143.779999  144.869995   63141600
# 2022-07-12  145.759995  148.449997  145.050003  145.860001   77588800
# 2022-07-13  142.990005  146.449997  142.119995  145.490005   71185600
# 2022-07-14  144.080002  148.949997  143.250000  148.470001   78140700
# 2022-07-15  149.779999  150.860001  148.199997  150.169998   75396045
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
start = '2018-10-24'
end = '2022-08-01'
        
AAPL_new = redate_data(AAPL, start, end)
AAPL_new['dv'] = np.array(AAPL_new.index.map(dt.datetime.toordinal))
AAPL_new
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2017-10-26   37.357198   37.499757   37.250281   37.399967   68002000
# 2017-10-27   37.846654   38.870695   37.706473   38.740017  177816800
# 2017-10-30   38.939591   39.932744   38.899200   39.611988  178803200
# 2017-10-31   39.892353   40.308145   39.664263   40.163212  144187200
# 2017-11-01   40.360417   40.377050   39.348259   39.652382  134551200
# ...                ...         ...         ...         ...        ...
# 2022-07-11  145.669998  146.639999  143.779999  144.869995   63141600
# 2022-07-12  145.759995  148.449997  145.050003  145.860001   77588800
# 2022-07-13  142.990005  146.449997  142.119995  145.490005   71185600
# 2022-07-14  144.080002  148.949997  143.250000  148.470001   78140700
# 2022-07-15  149.779999  150.860001  148.199997  150.169998   75396045
#
#             Dividends  Stock Splits      dv
# Date
# 2017-10-26        0.0           0.0  736628
# ...

# %%
start = '2015-10-24'
end = '2022-08-01'

bt = BackTest(AAPL, start, end)
bt.make_strategy()

# %%
bt.plot_bt()
# Out:
# <div>                            <div id="bd5524ce-ec92-4319-89b0-21f20751dc9a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd5524ce-ec92-4319-89b0-21f20751dc9a")) {                    Plotly.newPlot(                        "bd5524ce-ec92-4319-89b0-21f20751dc9a",                        [{"name":"Data","x":["2015-08-13T00:00:00","2015-08-14T00:00:00","2015-08-17T00:00:00","2015-08-18T00:00:00","2015-08-19T00:00:00","2015-08-20T00:00:00","2015-08-21T00:00:00","2015-08-24T00:00:00","2015-08-25T00:00:00","2015-08-26T00:00:00","2015-08-27T00:00:00","2015-08-28T00:00:00","2015-08-31T00:00:00","2015-09-01T00:00:00","2015-09-02T00:00:00","2015-09-03T00:00:00","2015-09-04T00:00:00","2015-09-08T00:00:00","2015-09-09T00:00:00","2015-09-10T00:00:00","2015-0
# ...

# %%
bt.make_trade()

# %%
bt.PS
# Out:
# Net Profit [$]           21118.098848
# Net Profit [%]             211.180988
# Total Closed Trades          8.000000
# Max Drawdown [$]         17485.868368
# Buy & Hold Return [$]    46986.497212
# Buy & Hold Return [%]      469.864972
# Profit Factor               13.795542
# Name: PS, dtype: float64
